# %%
files = []
with open('lista_comunidades.txt', 'r') as file:
    rows = file.readlines()
    for row in rows:
        files.append(row[:20])

# %%
files
# Out:
# ['2015-01-27-155113-eq',
#  '2015-01-27-155342-eq',
#  '2015-01-27-155517-eq',
#  '2015-01-27-155607-eq',
#  '2015-01-27-155845-eq',
#  '2015-01-27-155933-eq',
#  '2015-01-27-160012-eq',
#  '2015-01-27-160141-eq',
#  '2015-01-27-160219-os',
#  '2015-01-27-160500-eq',
#  '2015-01-27-160540-eq',
#  '2015-01-27-160632-eq',
#  '2015-01-27-160742-eq',
#  '2015-01-27-160940-eq',
#  '2015-01-27-161030-eq',
#  '2015-01-27-161114-eq',
#  '2015-01-27-161201-eq',
#  '2015-01-27-161241-eq',
#  '2015-01-27-161335-eq',
#  '2015-01-27-162801-eq',
#  '2015-01-27-162930-eq',
#  '2015-01-28-111704-eq',
#  '2015-01-28-112141-eq',
#  '2015-01-28-112256-eq',
#  '2015-01-28-112345-eq',
#  '2015-01-28-112529-eq',
#  '2015-01-28-112614-eq',
#  '2015-01-28-120053-eq',
#  '2015-01-28-120513-eq',
#  '2015-01-28-121339-os',
#  '2015-01-28-121446-eq',
#  '2015-01-28-121517-eq',
#  '2015-01-28-121627-eq',
#  '2015-01-28-121706-eq',
#  '2015-01-28-121754-eq',
#  '2015-01-28-121835-eq',
#  '2015-01-28-121931-eq',
# ...

# %%
rows
# Out:
# ['2015-01-27-155113-eq 5\n',
#  '2015-01-27-155342-eq 2\n',
#  '2015-01-27-155517-eq 3\n',
#  '2015-01-27-155607-eq 2\n',
#  '2015-01-27-155845-eq 4\n',
#  '2015-01-27-155933-eq 3\n',
#  '2015-01-27-160012-eq 2\n',
#  '2015-01-27-160141-eq 2\n',
#  '2015-01-27-160219-os 3\n',
#  '2015-01-27-160500-eq 3\n',
#  '2015-01-27-160540-eq 4\n',
#  '2015-01-27-160632-eq 7\n',
#  '2015-01-27-160742-eq 4\n',
#  '2015-01-27-160940-eq 6\n',
#  '2015-01-27-161030-eq 5\n',
#  '2015-01-27-161114-eq 4\n',
#  '2015-01-27-161201-eq 3\n',
#  '2015-01-27-161241-eq 2\n',
#  '2015-01-27-161335-eq 2\n',
#  '2015-01-27-162801-eq 5\n',
#  '2015-01-27-162930-eq 5\n',
#  '2015-01-28-111704-eq 2\n',
#  '2015-01-28-112141-eq 6\n',
#  '2015-01-28-112256-eq 1\n',
#  '2015-01-28-112345-eq 4\n',
#  '2015-01-28-112529-eq 3\n',
#  '2015-01-28-112614-eq 3\n',
#  '2015-01-28-120053-eq 2\n',
#  '2015-01-28-120513-eq 4\n',
#  '2015-01-28-121339-os 2\n',
#  '2015-01-28-121446-eq 4\n',
#  '2015-01-28-121517-eq 5\n',
# ...
